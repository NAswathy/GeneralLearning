# %%
#

# %%
 pip install selenium
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.12/site-packages (4.35.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (2025.7.14)
# Requirement already satisfied: typing_extensions~=4.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /opt/anaconda3/lib/python3.12/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import datetime

# %% [markdown]
# # Load the Excel file
# file_path = '/Users/aswathy.n/Desktop/QuickRegressionTesting1.xlsx'
# url_sheet_name = 'URLSheet'
# data_sheet_name = 'DataSheet'
#
# # Read the URL from the first sheet
# df_url = pd.read_excel(file_path, sheet_name=0)
# url_column = 'URL'
# base_url = df_url.at[0, url_column]
#
# # Read the input texts and expected responses from the specified sheet
# df_data = pd.read_excel(file_path, sheet_name=data_sheet_name)
# skuCol = 'SKU'
# questionCol = 'Question'
# expected_response_column = 'Expected Response'

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Load the Excel file
excel_file = pd.ExcelFile('/Users/aswathy.n/Desktop/QuickRegressionTesting5.xlsx')

# List all sheet names
sheet_names = excel_file.sheet_names
print("Sheet names:", sheet_names)

# Read the first sheet into a DataFrame
df_sheet1 = pd.read_excel(excel_file, sheet_name='URLSheet')
print("First sheet data:")
print(df_sheet1)
pdp_AIWidget_QA=df_sheet1.loc[1,'URL']

# Read the third sheet into a DataFrame
df_sheet3 = pd.read_excel(excel_file, sheet_name='QA-PDPAIWidget')
print("Third sheet data:")
print(df_sheet3.head())
# Out:
# Sheet names: ['URLSheet', 'Deployment_CountryList', 'MandatoryQs', 'MandatoryQ', 'Prod-PDPAIWidget', 'QA-PDPAIWidget', 'QuickQAPDPAIWidget', 'QuickProdPDPAIWidget', 'QA3-FSHS', 'QA-MagellenCitations', 'QA_Trials', 'Prod_trials', 'Sheet2']
# First sheet data:
#                                                  URL  \
# 0  https://www.thermofisher.com/order/catalog/pro...
# 1  https://www.qa.thermofisher.com/order/catalog/...
# 2  https://qa3.fishersci.com/us/en/customer-help-...
# 3  https://fishersci.com/us/en/customer-help-supp...
# 4  https://www.qa.thermofisher.com/antibody/produ...
#
#                        Email              Password
# 0  genaitestacc1@yopmail.com  01L{V1b#g&dYn'vmVVM:
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# Third sheet data:
#                                             Question       SKU  \
# 0                                        與 NP0006 比較    NP0007
# 1                          / 제품 지원을 받으려면 어떻게 해야 하나요?    NP0007
# 2                               MGPとBMP-2の結合を検出する方法     NP0006
# 3  list all the Vitamins and their Molecular weig...  11012044
# 4  which is the lighteste amino acid present in t...  31800022
#
#                                      Expected Answer
# 0  属性 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buff...
# 1  팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCust...
# 2  MGPとBMP-2の結合の検出方法\nMGPとBMP-2の結合を検出するために、FLAGとc...
# 3  Vitamins and Their Molecular Weights\nCholine ...
# 4  Lightest Amino Acid in RPMI 1640 Medium\nThe l...

# %%
pdp_AIWidget_QA
# Out:
# 'https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061'

# %%
# Initialize the web driver (make sure to have the appropriate driver for your browser)
driver = webdriver.Chrome() #executable_path='/Users/aswathy.n/Documents/chromedriver')
driver.maximize_window()

# %%
now=datetime.datetime.now()
formatted_date_time = now.strftime("%Y-%m-%d %H:%M:%S")
print ("current date time is "+ str(formatted_date_time))
# Out:
# current date time is 2026-03-05 19:28:53

# %% [markdown]
# #This is for hard coded run
# # Initialize lists to store results
# matches = []
# mismatches = []
#
# # Function to calculate cosine similarity
# def calculate_cosine_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     cosine_sim = cosine_similarity(vectors)
#     return cosine_sim[0][1]
#
# # Function to modify the URL
# def modify_url(base_url, new_value):
#     modified_url = re.sub(r'/product/[^?]+', f'/product/{new_value}', base_url)
#
#     modified_url = re.sub(r'srp-[^&]+', f'srp-{new_value}', modified_url)
#     modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
#     return modified_url
#
# # Initialize the previous URL modifier value
# previous_url_modifier = None
#
# # Open the web portal with the modified URL
# modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
# driver.get(modified_url)
#
#
# time.sleep(10)
#
# cookie_accept=driver.find_element(By.ID, 'truste-consent-button')
# cookie_accept.click()
# time.sleep(15)

# %%
# Initialize lists to store results
matches = []
mismatches = []

# Function to calculate cosine similarity
def calculate_cosine_similarity(text1, text2):
    vectorizer = TfidfVectorizer().fit_transform([text1, text2])
    vectors = vectorizer.toarray()
    cosine_sim = cosine_similarity(vectors)
    return cosine_sim[0][1]

# Function to modify the URL
def modify_url(base_url, new_value):
    modified_url = re.sub(r'/product/[^?]+', f'/product/{new_value}', base_url)
    
    modified_url = re.sub(r'srp-[^&]+', f'srp-{new_value}', modified_url)
   # modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
    print (modified_url, new_value)
    return modified_url

# Initialize the previous URL modifier value
previous_url_modifier = None

def set_cookie(driver, name, value):
    driver.add_cookie({'name': name, 'value': value})

# Function to delete the cookie
def delete_cookie(driver, name):
    driver.delete_cookie(name)

def login(driver, email, password):
    signin = driver.find_element(By.XPATH, "/html/body/header/div[2]/div[1]/div[3]/ul/li[3]/span")
    signin.click()
    time.sleep(2)
    signIn1 = driver.find_element(By.XPATH, "/html/body/header/div[2]/div[1]/div[3]/ul/li[4]/div/div/div[1]/div/a")
    signIn1.click()
    time.sleep(12)
    emailTextField = driver.find_element(By.ID, "username-field")
    emailTextField.click()
    emailTextField.send_keys(email)
    emailTextField.send_keys(Keys.RETURN)
    nextButton = driver.find_element(By.ID, "next-button")
    nextButton.click()
    time.sleep(5)
    passwordTextField=driver.find_element(By.ID, "password-field")
    passwordTextField.click()
    passwordTextField.send_keys(password)
    signInButton=driver.find_element(By.ID, "signin-button")
    signInButton.click()
    
    time.sleep(10)

# %%
# Open the web portal with the modified URL
base_url=pdp_AIWidget_QA
country_code='US'
driver.get(base_url)

time.sleep(10)

cookie_accept=driver.find_element(By.ID, 'truste-consent-button')
cookie_accept.click()
time.sleep(15)


# Delete the existing cookie CK_ISO_CODE
delete_cookie(driver, 'CK_ISO_CODE')
#Setting new value
set_cookie(driver, 'CK_ISO_CODE', country_code)

#login
login(driver, emailId, password)

driver.refresh()
time.sleep(10)

# %%
#To be included later!!!
# Iterate over the rows in the DataFrame
for index, row in df_sheet3.iterrows():
    SKU = row['SKU']
    Question = row['Question']
    expected_response = row['Expected Answer']
    print ("Question, expected_response, SKU")
    print (Question,expected_response, SKU)

    # Modify the URL only if the URL modifier value changes
    if SKU != previous_url_modifier:
        modified_url = modify_url(base_url, SKU)
        previous_url_modifier = SKU
        driver.get(modified_url)
        print (modified_url, base_url)
        time.sleep(10)
        # Click on the specific tab before entering the input text
        segment_tab = driver.find_element(By.CSS_SELECTOR, 'div > a') #
                                                   #  /html/body/div[9]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div
       # segment_tab.click()     #/html/body/div[10]/div/div[2]/div[2]/core-navigationbar/core-navigationbar-item[2]//div                   
        #/html/body/div[9]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div
        # /html/body/div[9]/div/div[2]/div[2]/core-navigationbar/core-navigationbar-item[2]//div/a 
        # Wait for the tab to load (adjust the sleep time as needed) #/html/body/div[9]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div/a
        time.sleep(2)
    else:
        driver.get(modified_url)
        time.sleep(10)
        print ("inside else")

    # Find the input field and enter the text
    input_field = driver.find_element(By.CSS_SELECTOR, '#search-component-wrapper-ssw > core-card > div > div.input-search-wrapper-ssw > core-search')  # Adjust the locator as needed
    input_field.click()                               #  '/html/body/div[9]/div/div[3]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div'
  #  input_field.clear()
    input_field.send_keys(Question)
    input_field.send_keys(Keys.RETURN)

    # Wait for the response to be generated (2 minutes)
    time.sleep(50)

    # Find the response field and get the text
    #response_field = driver.find_element(By.CLASS_NAME, 'input-search hydrated')  # Adjust the locator as needed
    #generated_response = response_field.text

   # response_field = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[2]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div/div[2]') # '//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div/div[2]/div/div[1]/div/div/div/div')  # Adjust the locator as needed
   #  response_field = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[3]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div')
   # response_field = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[3]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div/div[2]/div/div[1]/div/div/div')
   # response_field = driver.find_element(By.CSS_SELECTOR, '#search-component-wrapper-ssw > core-card > div > div.input-search-wrapper-ssw > core-search')
    response_field = driver.find_element(By.XPATH,'//*[@id="question-id-1"]/div[2]')
    generated_response = response_field.text       
    print("generated_response")
    print(generated_response)
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div/div[2]/div/div[1]/div/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[3]/div[2]/div/div[1]/div
    # Calculate cosine similarity
    similarity = calculate_cosine_similarity(generated_response, expected_response)

    # Compare the generated response with the expected response using cosine similarity
    if similarity >= 0.60:  # Threshold for considering a match (adjust as needed)
        matches.append((SKU,Question ,generated_response, expected_response, similarity))
    else:
        mismatches.append((SKU,Question ,generated_response, expected_response, similarity))

# Close the web driver
#driver.quit()

print(matches)
print(mismatches)
# Out:
# Question, expected_response, SKU
# 與 NP0006 比較 属性 NP0007 NP0006
# 产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)
# 目录编号 NP0007 NP0006
# 产品类型 LDS Sample Buffer Transfer Buffer
# 浓度 4X 20X
# 数量 10mL 125mL
# 价格 $23.46 USD $35.49 USD
# 储存条件 4°C to 25°C 室温
# 兼容胶类型 NuPAGE™ Gels NuPAGE™ Gels
# 运输条件 室温或湿冰 室温
# 保质期 未指定 6个月
# 库存状态 有库存 有库存
# i NP0007
# https://www.qa.thermofisher.com/order/catalog/product/NP0007?SID=srch-srp-NP0007 NP0007
# https://www.qa.thermofisher.com/order/catalog/product/NP0007?SID=srch-srp-NP0007 https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061
# generated_response
# 属性 NP0007 (NuPAGE™ LDS Sample Buffer (4X)) NP0006 (NuPAGE™ Transfer Buffer (20X))
# 产品编号 NP0007 NP0006
# 产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)
# 产品规格 10mL 125mL
# 浓度 4 X 20X
# 缓冲液类型 Sample Loading Buffers Transfer Buffers
# 产品类型 LDS Sample Buffer Transfer Buffer
# 凝胶兼容性 NuPAGE™ Gels NuPAGE™ Gels
# 产品线 NuPAGE™ NuPAGE™
# 储存条件 4°C 到 25°C 室温
# 运输条件 室温或湿冰运输 室温运输
# 价格 (USD) 24.34 36.81
# 库存状态 In Stock Out Of Stock
# 保质期 未特别说明 6 个月
# Give feedback
# Question, expected_response, SKU
# / 제품 지원을 받으려면 어떻게 해야 하나요? 팀에 연락할 수 있는 연락처 정보입니다.
# How can we help?
# Customer Service
# 800 955 6288
# Customercare@thermofisher.com
# Technical Support
# 800 955 6288
# Contact Technical Support
# Instrument Service
# 800 955 6288
# Contact Instrument Service
# Sales
# Live Chat NP0007
# inside else
# generated_response
# 팀에 연락할 수 있는 연락처 정보입니다.
# How can we help?
# Customer Service
# 123456789
# Contact Customer Service
# Technical Support
# 1234567891
# Contact Technical Support
# Instrument Service
# 1234567893
# Random3@gmail.com
# Sales
# Live Chat
# Can't find what you're looking for?
# Find additional support.
# Give feedback
# Question, expected_response, SKU
# MGPとBMP-2の結合を検出する方法  MGPとBMP-2の結合の検出方法
# MGPとBMP-2の結合を検出するために、FLAGとc-Mycでタグ付けされたMGPとBMP-2を使用して免疫沈降を行いました。結果は、MGPとBMP-2の共沈を示しました。
# Binding Detection of MGP and BMP-2
# To detect binding between MGP and BMP-2, we performed immunoprecipitation using MGP and BMP-2 tagged with FLAG and c-Myc. The results showed co-precipitation of BMP-2 with MGP.
# Sources 1
# 追加データと参考資料
# 1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.
# 2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
# 3. NuPAGE Tris-Acetate Gels
# 4. Western Blot Buffers
# 5. Blocking Buffers for Western Blot and ELISA
# 6. Native PAGE Gels
# 7. NuPAGE Technical Guide (Page: 43)
# 8. NuPAGE Large Protein Analysis System (Page: 30) NP0006
# https://www.qa.thermofisher.com/order/catalog/product/NP0006?SID=srch-srp-NP0006 NP0006
# https://www.qa.thermofisher.com/order/catalog/product/NP0006?SID=srch-srp-NP0006 https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061
# generated_response
# MGPとBMP-2の結合検出方法
# MGP（Matrix GLA protein）とBMP-2（bone morphogenetic protein-2）の結合を検出するために、FLAGタグ付きMGPとc-Mycタグ付きBMP-2を用いた免疫沈降法が実施されました。この方法により、MGPとBMP-2の共沈降が確認され、両者の結合が示されました。
# さらに、BMP-2の活性に対するMGPの影響を定量化するために、アルカリホスファターゼ活性のアッセイが行われました。
# これらの方法により、MGPがBMP-2の調節タンパク質であることが示唆されました。
# Sources 1
# 追加データと参考資料
# 1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.
# 2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
# 3. NuPAGE Tris-Acetate Gels
# 4. Blocking Buffers for Western Blot and ELISA
# 5. Western Blot Buffers
# 6. NuPAGE Large Protein Analysis System (Page: 20, 30)
# 7. NuPAGE Technical Guide (Page: 34)
# Give feedback
# Question, expected_response, SKU
# list all the Vitamins and their Molecular weights? Vitamins and Their Molecular Weights
# Choline chloride: 140.0
# D-Calcium pantothenate: 477.0
# Folic Acid: 441.0
# Niacinamide: 122.0
# Pyridoxal hydrochloride: 204.0
# Riboflavin: 376.0
# Thiamine hydrochloride: 337.0
# i-Inositol: 180.0
# Sources 1
# Additional Data & References
# 1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.205 (Page: 1)
# 2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)
# 3. Cell Culture Media Preparation from Powder
# 4. FAQ:Where can I find media formulations?
#
# 5. FAQ:Where can I find the osmolality for MEM Medium?
#
# 6. FAQ:Do you have a comparison of dishes, culture plates, and flasks by surface area, seeding density, cells at confluency, and volumes of Versene solution, trypsin, and growth medium? 11012044
# https://www.qa.thermofisher.com/order/catalog/product/11012044?SID=srch-srp-11012044 11012044
# https://www.qa.thermofisher.com/order/catalog/product/11012044?SID=srch-srp-11012044 https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061
# generated_response
# Generating response
# Question, expected_response, SKU
# which is the lighteste amino acid present in this? Lightest Amino Acid in RPMI 1640 Medium
# The lightest amino acid present in RPMI 1640 Medium is Glycine, with a molecular weight of 75.0.
# Sources 1
# Additional Data & References
# 1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.119 (Page: 1)
# 2. Cell Culture Media Preparation from Powder
# 3. Flyer: Gibco custom media manufacturing (Page: 1)
# 4. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)
# 5. FAQ:What is the density (g/L) for RPMI 1640 Medium?
#
# 6. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light? 31800022
# https://www.qa.thermofisher.com/order/catalog/product/31800022?SID=srch-srp-31800022 31800022
# https://www.qa.thermofisher.com/order/catalog/product/31800022?SID=srch-srp-31800022 https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061
# generated_response
# Lightest Amino Acid in RPMI 1640 Medium (Catalog Number 31800022)
# The provided product information for RPMI 1640 Medium (Catalog Number 31800022) does not specify the individual amino acids present, nor does it identify which is the lightest amino acid in the formulation.
# RPMI 1640 Medium is a complex cell culture medium containing various components including amino acids, vitamins, and other nutrients, but specific details on the amino acid composition or their molecular weights are not included in the available documentation.
# For detailed amino acid composition, please refer to the complete formulation or contact our Technical Support Team for assistance.
# Additional Data & References
# 1. Flyer: Gibco custom media manufacturing (Page: 1)
# 2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)
# 3. FAQ:What is the density (g/L) for RPMI 1640 Medium?
#
# 4. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?
#
# 5. FAQ:Can the Gibco Media Configurator be used for my own proprietary formulation?
#
# 6. FAQ:Where can I find media formulations?
#
# Give feedback
# Question, expected_response, SKU
# how many nasel swabs were plated on each test medium and examined after each overnight? Nasal Swabs Plated on Each Test Medium
# A total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.
# Sources 1
# Additional Data & References
# 1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2, 3)
# 2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3)
# 3. Spectra MRSA (Page: 1, 2) R01822
# https://www.qa.thermofisher.com/order/catalog/product/R01822?SID=srch-srp-R01822 R01822
# https://www.qa.thermofisher.com/order/catalog/product/R01822?SID=srch-srp-R01822 https://www.qa.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061
# generated_response
# Number of Nasal Swabs Plated on Each Test Medium
# A total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.
# Sources 1
# Additional Data & References
# 1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2)
# 2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3, 4)
# 3. Spectra MRSA (Page: 1, 2)
# Give feedback
# [('NP0007', '與 NP0006 比較', '属性 NP0007 (NuPAGE™ LDS Sample Buffer (4X)) NP0006 (NuPAGE™ Transfer Buffer (20X))\n产品编号 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n产品规格 10mL 125mL\n浓度 4 X 20X\n缓冲液类型 Sample Loading Buffers Transfer Buffers\n产品类型 LDS Sample Buffer Transfer Buffer\n凝胶兼容性 NuPAGE™ Gels NuPAGE™ Gels\n产品线 NuPAGE™ NuPAGE™\n储存条件 4°C 到 25°C 室温\n运输条件 室温或湿冰运输 室温运输\n价格 (USD) 24.34 36.81\n库存状态 In Stock Out Of Stock\n保质期 未特别说明 6 个月\nGive feedback', '属性 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n目录编号 NP0007 NP0006\n产品类型 LDS Sample Buffer Transfer Buffer\n浓度 4X 20X\n数量 10mL 125mL\n价格 $23.46 USD $35.49 USD\n储存条件 4°C to 25°C 室温\n兼容胶类型 NuPAGE™ Gels NuPAGE™ Gels\n运输条件 室温或湿冰 室温\n保质期 未指定 6个月\n库存状态 有库存 有库存\ni', 0.712397743853218), ('NP0006', 'MGPとBMP-2の結合を検出する方法\xa0', 'MGPとBMP-2の結合検出方法\nMGP（Matrix GLA protein）とBMP-2（bone morphogenetic protein-2）の結合を検出するために、FLAGタグ付きMGPとc-Mycタグ付きBMP-2を用いた免疫沈降法が実施されました。この方法により、MGPとBMP-2の共沈降が確認され、両者の結合が示されました。\nさらに、BMP-2の活性に対するMGPの影響を定量化するために、アルカリホスファターゼ活性のアッセイが行われました。\nこれらの方法により、MGPがBMP-2の調節タンパク質であることが示唆されました。\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Blocking Buffers for Western Blot and ELISA\n5. Western Blot Buffers\n6. NuPAGE Large Protein Analysis System (Page: 20, 30)\n7. NuPAGE Technical Guide (Page: 34)\nGive feedback', 'MGPとBMP-2の結合の検出方法\nMGPとBMP-2の結合を検出するために、FLAGとc-Mycでタグ付けされたMGPとBMP-2を使用して免疫沈降を行いました。結果は、MGPとBMP-2の共沈を示しました。\nBinding Detection of MGP and BMP-2\nTo detect binding between MGP and BMP-2, we performed immunoprecipitation using MGP and BMP-2 tagged with FLAG and c-Myc. The results showed co-precipitation of BMP-2 with MGP.\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Western Blot Buffers\n5. Blocking Buffers for Western Blot and ELISA\n6. Native PAGE Gels\n7. NuPAGE Technical Guide (Page: 43)\n8. NuPAGE Large Protein Analysis System (Page: 30)', 0.6359406056595461), ('31800022', 'which is the lighteste amino acid present in this?', 'Lightest Amino Acid in RPMI 1640 Medium (Catalog Number 31800022)\nThe provided product information for RPMI 1640 Medium (Catalog Number 31800022) does not specify the individual amino acids present, nor does it identify which is the lightest amino acid in the formulation.\nRPMI 1640 Medium is a complex cell culture medium containing various components including amino acids, vitamins, and other nutrients, but specific details on the amino acid composition or their molecular weights are not included in the available documentation.\nFor detailed amino acid composition, please refer to the complete formulation or contact our Technical Support Team for assistance.\nAdditional Data & References\n1. Flyer: Gibco custom media manufacturing (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n4. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?\n\n5. FAQ:Can the Gibco Media Configurator be used for my own proprietary formulation?\n\n6. FAQ:Where can I find media formulations?\n\nGive feedback', 'Lightest Amino Acid in RPMI 1640 Medium\nThe lightest amino acid present in RPMI 1640 Medium is Glycine, with a molecular weight of 75.0.\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.119 (Page: 1)\n2. Cell Culture Media Preparation from Powder\n3. Flyer: Gibco custom media manufacturing (Page: 1)\n4. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n5. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n6. FAQ:How light sensit ...
# [('NP0007', '/ 제품 지원을 받으려면 어떻게 해야 하나요?', "팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n123456789\nContact Customer Service\nTechnical Support\n1234567891\nContact Technical Support\nInstrument Service\n1234567893\nRandom3@gmail.com\nSales\nLive Chat\nCan't find what you're looking for?\nFind additional support.\nGive feedback", '팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n800 955 6288\nCustomercare@thermofisher.com\nTechnical Support\n800 955 6288\nContact Technical Support\nInstrument Service\n800 955 6288\nContact Instrument Service\nSales\nLive Chat', 0.46546817465104184), ('11012044', 'list all the Vitamins and their Molecular weights?', 'Generating response', 'Vitamins and Their Molecular Weights\nCholine chloride: 140.0\nD-Calcium pantothenate: 477.0\nFolic Acid: 441.0\nNiacinamide: 122.0\nPyridoxal hydrochloride: 204.0\nRiboflavin: 376.0\nThiamine hydrochloride: 337.0\ni-Inositol: 180.0\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.205 (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. Cell Culture Media Preparation from Powder\n4. FAQ:Where can I find media formulations?\n\n5. FAQ:Where can I find the osmolality for MEM Medium?\n\n6. FAQ:Do you have a comparison of dishes, culture plates, and flasks by surface area, seeding density, cells at confluency, and volumes of Versene solution, trypsin, and growth medium?', 0.0)]

# %%
matches
# Out:
# [('NP0007',
#   '與 NP0006 比較',
#   '属性 NP0007 (NuPAGE™ LDS Sample Buffer (4X)) NP0006 (NuPAGE™ Transfer Buffer (20X))\n产品编号 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n产品规格 10mL 125mL\n浓度 4 X 20X\n缓冲液类型 Sample Loading Buffers Transfer Buffers\n产品类型 LDS Sample Buffer Transfer Buffer\n凝胶兼容性 NuPAGE™ Gels NuPAGE™ Gels\n产品线 NuPAGE™ NuPAGE™\n储存条件 4°C 到 25°C 室温\n运输条件 室温或湿冰运输 室温运输\n价格 (USD) 24.34 36.81\n库存状态 In Stock Out Of Stock\n保质期 未特别说明 6 个月\nGive feedback',
#   '属性 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n目录编号 NP0007 NP0006\n产品类型 LDS Sample Buffer Transfer Buffer\n浓度 4X 20X\n数量 10mL 125mL\n价格 $23.46 USD $35.49 USD\n储存条件 4°C to 25°C 室温\n兼容胶类型 NuPAGE™ Gels NuPAGE™ Gels\n运输条件 室温或湿冰 室温\n保质期 未指定 6个月\n库存状态 有库存 有库存\ni',
#   0.712397743853218),
#  ('NP0006',
#   'MGPとBMP-2の結合を検出する方法\xa0',
#   'MGPとBMP-2の結合検出方法\nMGP（Matrix GLA protein）とBMP-2（bone morphogenetic protein-2）の結合を検出するために、FLAGタグ付きMGPとc-Mycタグ付きBMP-2を用いた免疫沈降法が実施されました。この方法により、MGPとBMP-2の共沈降が確認され、両者の結合が示されました。\nさらに、BMP-2の活性に対するMGPの影響を定量化するために、アルカリホスファターゼ活性のアッセイが行われました。\nこれらの方法により、MGPがBMP-2の調節タンパク質であることが示唆されました。\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Blocking Buffers for Western Blot and ELISA\n5. Western Blot Buffers\n6. NuPAGE Large Protein Analysis System (Page: 20, 30)\n7. NuPAGE Technical Guide (Page: 34)\nGive feedback',
#   'MGPとBMP-2の結合の検出方法\nMGPとBMP-2の結合を検出するために、FLAGとc-Mycでタグ付けされたMGPとBMP-2を使用して免疫沈降を行いました。結果は、MGPとBMP-2の共沈を示しました。\nBinding Detection of MGP and BMP-2\nTo detect binding between MGP and BMP-2, we performed immunoprecipitation using MGP and BMP-2 tagged with FLAG and c-Myc. The results showed co-precipitation of BMP-2 with MGP.\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Western Blot Buffers\n5. Blocking Buffers for Western Blot and ELISA\n6. Native PAGE Gels\n7. NuPAGE Technical Guide (Page: 43)\n8. NuPAGE Large Protein Analysis System (Page: 30)',
#   0.6359406056595461),
#  ('31800022',
#   'which is the lighteste amino acid present in this?',
#   'Lightest Amino Acid in RPMI 1640 Medium (Catalog Number 31800022)\nThe provided product information for RPMI 1640 Medium (Catalog Number 31800022) does not specify the individual amino acids present, nor does it identify which is the lightest amino acid in the formulation.\nRPMI 1640 Medium is a complex cell culture medium containing various components including amino acids, vitamins, and other nutrients, but specific details on the amino acid composition or their molecular weights are not included in the available documentation.\nFor detailed amino acid composition, please refer to the complete formulation or contact our Technical Support Team for assistance.\nAdditional Data & References\n1. Flyer: Gibco custom media manufacturing (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n4. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?\n\n5. FAQ:Can the Gibco Media Configurator be used for my own proprietary formulation?\n\n6. FAQ:Where can I find media formulations?\n\nGive feedback',
#   'Lightest Amino Acid in RPMI 1640 Medium\nThe lightest amino acid present in RPMI 1640 Medium is Glycine, with a molecular weight of 75.0.\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.119 (Page: 1)\n2. Cell Culture Media Preparation from Powder\n3. Flyer: Gibco custom media manufacturing (Page: 1)\n4. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n5. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n6. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?',
#   0.6666135945367544),
#  ('R01822',
#   'how many nasel swabs were plated on each test medium and examined after each overnight?',
#   'Number of Nasal Swabs Plated on Each Test Medium\nA total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.\nSources 1\nAdditional Data & References\n1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2)\n2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3, 4)\n3. Spectra MRSA (Page: 1, 2)\nGive feedback',
#   'Nasal Swabs Plated on Each Test Medium\nA total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.\nSources 1\nAdditional Data & References\n1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2, 3)\n2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3)\n3. Spectra MRSA (Page: 1, 2)',
#   0.9755791780340227)]

# %%
mismatches
# Out:
# [('NP0007',
#   '/ 제품 지원을 받으려면 어떻게 해야 하나요?',
#   "팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n123456789\nContact Customer Service\nTechnical Support\n1234567891\nContact Technical Support\nInstrument Service\n1234567893\nRandom3@gmail.com\nSales\nLive Chat\nCan't find what you're looking for?\nFind additional support.\nGive feedback",
#   '팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n800 955 6288\nCustomercare@thermofisher.com\nTechnical Support\n800 955 6288\nContact Technical Support\nInstrument Service\n800 955 6288\nContact Instrument Service\nSales\nLive Chat',
#   0.46546817465104184),
#  ('11012044',
#   'list all the Vitamins and their Molecular weights?',
#   'Generating response',
#   'Vitamins and Their Molecular Weights\nCholine chloride: 140.0\nD-Calcium pantothenate: 477.0\nFolic Acid: 441.0\nNiacinamide: 122.0\nPyridoxal hydrochloride: 204.0\nRiboflavin: 376.0\nThiamine hydrochloride: 337.0\ni-Inositol: 180.0\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.205 (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. Cell Culture Media Preparation from Powder\n4. FAQ:Where can I find media formulations?\n\n5. FAQ:Where can I find the osmolality for MEM Medium?\n\n6. FAQ:Do you have a comparison of dishes, culture plates, and flasks by surface area, seeding density, cells at confluency, and volumes of Versene solution, trypsin, and growth medium?',
#   0.0)]

# %%
now=datetime.datetime.now()
formatted_date_time = now.strftime("%Y-%m-%d %H:%M:%S")
print ("current date time is "+ str(formatted_date_time))
# Out:
# current date time is 2026-03-05 19:36:32

# %%
matches
# Out:
# [('NP0007',
#   '與 NP0006 比較',
#   '属性 NP0007 (NuPAGE™ LDS Sample Buffer (4X)) NP0006 (NuPAGE™ Transfer Buffer (20X))\n产品编号 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n产品规格 10mL 125mL\n浓度 4 X 20X\n缓冲液类型 Sample Loading Buffers Transfer Buffers\n产品类型 LDS Sample Buffer Transfer Buffer\n凝胶兼容性 NuPAGE™ Gels NuPAGE™ Gels\n产品线 NuPAGE™ NuPAGE™\n储存条件 4°C 到 25°C 室温\n运输条件 室温或湿冰运输 室温运输\n价格 (USD) 24.34 36.81\n库存状态 In Stock Out Of Stock\n保质期 未特别说明 6 个月\nGive feedback',
#   '属性 NP0007 NP0006\n产品名称 NuPAGE™ LDS Sample Buffer (4X) NuPAGE™ Transfer Buffer (20X)\n目录编号 NP0007 NP0006\n产品类型 LDS Sample Buffer Transfer Buffer\n浓度 4X 20X\n数量 10mL 125mL\n价格 $23.46 USD $35.49 USD\n储存条件 4°C to 25°C 室温\n兼容胶类型 NuPAGE™ Gels NuPAGE™ Gels\n运输条件 室温或湿冰 室温\n保质期 未指定 6个月\n库存状态 有库存 有库存\ni',
#   0.712397743853218),
#  ('NP0006',
#   'MGPとBMP-2の結合を検出する方法\xa0',
#   'MGPとBMP-2の結合検出方法\nMGP（Matrix GLA protein）とBMP-2（bone morphogenetic protein-2）の結合を検出するために、FLAGタグ付きMGPとc-Mycタグ付きBMP-2を用いた免疫沈降法が実施されました。この方法により、MGPとBMP-2の共沈降が確認され、両者の結合が示されました。\nさらに、BMP-2の活性に対するMGPの影響を定量化するために、アルカリホスファターゼ活性のアッセイが行われました。\nこれらの方法により、MGPがBMP-2の調節タンパク質であることが示唆されました。\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Blocking Buffers for Western Blot and ELISA\n5. Western Blot Buffers\n6. NuPAGE Large Protein Analysis System (Page: 20, 30)\n7. NuPAGE Technical Guide (Page: 34)\nGive feedback',
#   'MGPとBMP-2の結合の検出方法\nMGPとBMP-2の結合を検出するために、FLAGとc-Mycでタグ付けされたMGPとBMP-2を使用して免疫沈降を行いました。結果は、MGPとBMP-2の共沈を示しました。\nBinding Detection of MGP and BMP-2\nTo detect binding between MGP and BMP-2, we performed immunoprecipitation using MGP and BMP-2 tagged with FLAG and c-Myc. The results showed co-precipitation of BMP-2 with MGP.\nSources 1\n追加データと参考資料\n1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.\n2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n3. NuPAGE Tris-Acetate Gels\n4. Western Blot Buffers\n5. Blocking Buffers for Western Blot and ELISA\n6. Native PAGE Gels\n7. NuPAGE Technical Guide (Page: 43)\n8. NuPAGE Large Protein Analysis System (Page: 30)',
#   0.6359406056595461),
#  ('31800022',
#   'which is the lighteste amino acid present in this?',
#   'Lightest Amino Acid in RPMI 1640 Medium (Catalog Number 31800022)\nThe provided product information for RPMI 1640 Medium (Catalog Number 31800022) does not specify the individual amino acids present, nor does it identify which is the lightest amino acid in the formulation.\nRPMI 1640 Medium is a complex cell culture medium containing various components including amino acids, vitamins, and other nutrients, but specific details on the amino acid composition or their molecular weights are not included in the available documentation.\nFor detailed amino acid composition, please refer to the complete formulation or contact our Technical Support Team for assistance.\nAdditional Data & References\n1. Flyer: Gibco custom media manufacturing (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n4. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?\n\n5. FAQ:Can the Gibco Media Configurator be used for my own proprietary formulation?\n\n6. FAQ:Where can I find media formulations?\n\nGive feedback',
#   'Lightest Amino Acid in RPMI 1640 Medium\nThe lightest amino acid present in RPMI 1640 Medium is Glycine, with a molecular weight of 75.0.\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.119 (Page: 1)\n2. Cell Culture Media Preparation from Powder\n3. Flyer: Gibco custom media manufacturing (Page: 1)\n4. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n5. FAQ:What is the density (g/L) for RPMI 1640 Medium?\n\n6. FAQ:How light sensitive is RPMI 1640 media? Should I also be protecting it from LED light?',
#   0.6666135945367544),
#  ('R01822',
#   'how many nasel swabs were plated on each test medium and examined after each overnight?',
#   'Number of Nasal Swabs Plated on Each Test Medium\nA total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.\nSources 1\nAdditional Data & References\n1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2)\n2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3, 4)\n3. Spectra MRSA (Page: 1, 2)\nGive feedback',
#   'Nasal Swabs Plated on Each Test Medium\nA total of 670 nasal swabs were plated on each test medium and examined after overnight (16 to 24 hours) incubation.\nSources 1\nAdditional Data & References\n1. Evaluation of a Novel Agar Medium from Remel to Screen for Methicillin Resistant Staphylococcus aureus (Page: 1, 2, 3)\n2. Comparison of Four Media for the Detection of Methicillin-Resistant Staphylococcus aureus (MRSA) from Nasal Swabs (Page: 1, 2, 3)\n3. Spectra MRSA (Page: 1, 2)',
#   0.9755791780340227)]

# %%
mismatches
# Out:
# [('NP0007',
#   '/ 제품 지원을 받으려면 어떻게 해야 하나요?',
#   "팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n123456789\nContact Customer Service\nTechnical Support\n1234567891\nContact Technical Support\nInstrument Service\n1234567893\nRandom3@gmail.com\nSales\nLive Chat\nCan't find what you're looking for?\nFind additional support.\nGive feedback",
#   '팀에 연락할 수 있는 연락처 정보입니다.\nHow can we help?\nCustomer Service\n800 955 6288\nCustomercare@thermofisher.com\nTechnical Support\n800 955 6288\nContact Technical Support\nInstrument Service\n800 955 6288\nContact Instrument Service\nSales\nLive Chat',
#   0.46546817465104184),
#  ('11012044',
#   'list all the Vitamins and their Molecular weights?',
#   'Generating response',
#   'Vitamins and Their Molecular Weights\nCholine chloride: 140.0\nD-Calcium pantothenate: 477.0\nFolic Acid: 441.0\nNiacinamide: 122.0\nPyridoxal hydrochloride: 204.0\nRiboflavin: 376.0\nThiamine hydrochloride: 337.0\ni-Inositol: 180.0\nSources 1\nAdditional Data & References\n1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.205 (Page: 1)\n2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)\n3. Cell Culture Media Preparation from Powder\n4. FAQ:Where can I find media formulations?\n\n5. FAQ:Where can I find the osmolality for MEM Medium?\n\n6. FAQ:Do you have a comparison of dishes, culture plates, and flasks by surface area, seeding density, cells at confluency, and volumes of Versene solution, trypsin, and growth medium?',
#   0.0)]

# %%
matchingResults="matches_report_QAPDP_"+country_code+"_"+str(now.strftime("%Y-%m-%d %H_%M_%S"))+".csv"
mismatchingResults="mismatches_report_QAPDP_"+country_code+"_"+str(now.strftime("%Y-%m-%d %H_%M_%S"))+".csv"

# %%
matchingResults, mismatchingResults
# Out:
# ('matches_report_QAPDP_US_2026-03-05 19_36_32.csv',
#  'mismatches_report_QAPDP_US_2026-03-05 19_36_32.csv')

# %%
import datetime
# Generate the report
matches_report = pd.DataFrame(matches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
matches_report.to_csv(matchingResults, index=False)

mismatches_report = pd.DataFrame(mismatches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
mismatches_report.to_csv(mismatchingResults, index=False)

print("Report generated successfully.")
# Out:
# Report generated successfully.

# %% [markdown]
# # Generate the report
# matches_report = pd.DataFrame(matches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
# matches_report.to_excel('matches_report_QA.xlsx', index=False)
#
# mismatches_report = pd.DataFrame(mismatches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
# mismatches_report.to_excel('mismatches_report_QA.xlsx', index=False)
#
# print("Report generated successfully.")
