# %%
#

# %%
 pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.35.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting urllib3<3.0,>=2.5.0 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (2025.7.14)
# Collecting typing_extensions~=4.14.0 (from selenium)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.30.0->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (3.7)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Downloading selenium-4.35.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 1.2 MB/s eta 0:00:00a 0:00:010m
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, typing_extensions, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.35.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.14.1 urllib3-2.5.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /opt/anaconda3/lib/python3.12/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import datetime

# %% [markdown]
# # Load the Excel file
# file_path = '/Users/aswathy.n/Desktop/QuickRegressionTesting1.xlsx'
# url_sheet_name = 'URLSheet'
# data_sheet_name = 'DataSheet'
#
# # Read the URL from the first sheet
# df_url = pd.read_excel(file_path, sheet_name=0)
# url_column = 'URL'
# base_url = df_url.at[0, url_column]
#
# # Read the input texts and expected responses from the specified sheet
# df_data = pd.read_excel(file_path, sheet_name=data_sheet_name)
# skuCol = 'SKU'
# questionCol = 'Question'
# expected_response_column = 'Expected Response'

# %%
# Load the Excel file
excel_file = pd.ExcelFile('QuickRegressionTesting5.xlsx')

# List all sheet names
sheet_names = excel_file.sheet_names[0]
print("Sheet names:", sheet_names)

# Read the first sheet into a DataFrame
df_sheet1 = pd.read_excel(excel_file, sheet_name='URLSheet')
print("First sheet data:")
print(df_sheet1.shape)
pdp_AIWidget_Prod=df_sheet1.loc[0,'URL']

# Read the third sheet into a DataFrame
df_sheetQs = pd.read_excel(excel_file, sheet_name='QuickProdPDPAIWidget')
print("A few Test Qs and ans: ")
print(df_sheetQs.head())

df_sheet1 = pd.read_excel(excel_file, sheet_name='URLSheet')
print("First sheet data:")
print(df_sheet1)
emailId=df_sheet1.loc[0,'Email']
password=df_sheet1.loc[0,'Password']

#emailId = "genaitestacc1@yopmail.com"
#password = "01L{V1b#g&dYn'vmVVM:"
emailId, password
# Out:
# Sheet names: URLSheet
# First sheet data:
# (5, 3)
# A few Test Qs and ans:
#                        Question_US  SKU_US  \
# 0         what is price of product  Np0006
# 1     Is there contact  us details  Np0006
# 2  Is this available for purchase?  Np0006
# 3                      promo codes  Np0006
# 4                              SDS  Np0006
#
#                                   Expected Answer_US
# 0  The price of the product NP0006 (NuPAGE™ Trans...
# 1  Concentration of NuPAGE Transfer Buffer (20X) ...
# 2  Here is the contact information to reach our t...
# 3  Yes, the product NP0006 (NuPAGE™ Transfer Buff...
# 4  Currently, there are no active promotions or d...
# First sheet data:
#                                                  URL  \
# 0  https://www.thermofisher.com/order/catalog/pro...
# 1  https://www.qa.thermofisher.com/order/catalog/...
# 2  https://qa3.fishersci.com/us/en/customer-help-...
# 3  https://fishersci.com/us/en/customer-help-supp...
# 4  https://www.qa.thermofisher.com/antibody/produ...
#
#                        Email              Password
# 0  genaitestacc1@yopmail.com  01L{V1b#g&dYn'vmVVM:
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ('genaitestacc1@yopmail.com', "01L{V1b#g&dYn'vmVVM:")

# %%
pdp_AIWidget_Prod
# Out:
# 'https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061'

# %%
import datetime
now=datetime.datetime.now()
print ("current date time is "+ str(now.time()))
# Out:
# current date time is 22:25:55.288465

# %%
# Initialize the web driver (make sure to have the appropriate driver for your browser)
driver = webdriver.Chrome() #executable_path='/Users/aswathy.n/Documents/chromedriver')
driver.maximize_window()

# %% [markdown]
# #This is for hard coded run
# # Initialize lists to store results
# matches = []
# mismatches = []
#
# # Function to calculate cosine similarity
# def calculate_cosine_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     cosine_sim = cosine_similarity(vectors)
#     return cosine_sim[0][1]
#
# # Function to modify the URL
# def modify_url(base_url, new_value):
#     modified_url = re.sub(r'/product/[^?]+', f'/product/{new_value}', base_url)
#
#     modified_url = re.sub(r'srp-[^&]+', f'srp-{new_value}', modified_url)
#     modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
#     return modified_url
#
# # Initialize the previous URL modifier value
# previous_url_modifier = None
#
# # Open the web portal with the modified URL
# modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
# driver.get(modified_url)
#
#
# time.sleep(10)
#
# cookie_accept=driver.find_element(By.ID, 'truste-consent-button')
# cookie_accept.click()
# time.sleep(15)

# %%
# Initialize lists to store results
matches = []
mismatches = []


# Function to calculate cosine similarity
def calculate_cosine_similarity(text1, text2):
    vectorizer = TfidfVectorizer().fit_transform([text1, text2])
    vectors = vectorizer.toarray()
    cosine_sim = cosine_similarity(vectors)
    return cosine_sim[0][1]

# Function to modify the URL
def modify_url(base_url, new_value):
    modified_url = re.sub(r'/product/[^?]+', f'/product/{new_value}', base_url)
    
    modified_url = re.sub(r'srp-[^&]+', f'srp-{new_value}', modified_url)
   # modified_url="https://www.thermofisher.com/order/catalog/product/NP00061?SID=srch-srp-NP00061"
    print ("modified_url")
    print (modified_url, new_value)
    return modified_url

# Initialize the previous URL modifier value
previous_url_modifier = None

def set_cookie(driver, name, value):
    driver.add_cookie({'name': name, 'value': value})

# Function to delete the cookie
def delete_cookie(driver, name):
    driver.delete_cookie(name)

def login(driver, email, password):
    signin = driver.find_element(By.XPATH, "/html/body/header/div[2]/div[1]/div[3]/ul/li[3]/span")
    signin.click()
    time.sleep(5)
    signIn1 = driver.find_element(By.XPATH, "/html/body/header/div[2]/div[1]/div[3]/ul/li[3]/div/div/div[1]/div/a")
    signIn1.click()
    time.sleep(12)
    emailTextField = driver.find_element(By.ID, "username-field")
    emailTextField.click()
    emailTextField.send_keys(email)
    emailTextField.send_keys(Keys.RETURN)
    nextButton = driver.find_element(By.ID, "next-button")
    nextButton.click()
    time.sleep(5)
    passwordTextField=driver.find_element(By.ID, "password-field")
    passwordTextField.click()
    passwordTextField.send_keys(password)
    signInButton=driver.find_element(By.ID, "signin-button")
    signInButton.click()
    
    time.sleep(10)

# %%
# Open the web portal with the modified URL
base_url=pdp_AIWidget_Prod
driver.get(base_url)
country_code='US'

time.sleep(10)

cookie_accept=driver.find_element(By.ID, 'truste-consent-button')
cookie_accept.click()
time.sleep(15)


# Delete the existing cookie CK_ISO_CODE
delete_cookie(driver, 'CK_ISO_CODE')
#Setting new value
set_cookie(driver, 'CK_ISO_CODE', country_code)

#login
login(driver, emailId, password)


driver.refresh()
time.sleep(5)

# %%
matches
# Out:
# []

# %%
#To be included later!!!
# Iterate over the rows in the DataFrame
for index, row in df_sheetQs.iterrows():
    SKU = row['SKU_US']
    Question = row['Question_US']
    expected_response = row['Expected Answer_US']
    print (SKU, expected_response, previous_url_modifier)

    # Modify the URL only if the URL modifier value changes
    if SKU != previous_url_modifier:
        modified_url = modify_url(base_url, SKU)
        previous_url_modifier = SKU
        driver.get(modified_url)
        time.sleep(15)
        # Click on the specific tab before entering the input text #/html/body/div[10]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div
        segment_tab = driver.find_element(By.XPATH, '/html/body/div[10]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div') #
                                                    
       # segment_tab.click()     #/html/body/div[10]/div/div[2]/div[2]/core-navigationbar/core-navigationbar-item[2]//div                   
        #/html/body/div[9]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div
        # /html/body/div[9]/div/div[2]/div[2]/core-navigationbar/core-navigationbar-item[2]//div/a 
        # Wait for the tab to load (adjust the sleep time as needed) #/html/body/div[9]/div/div[3]/div[2]/core-navigationbar/core-navigationbar-item[2]//div/a
        time.sleep(2)
    else:
        driver.get(modified_url)
        print ("inside else")
        time.sleep(5)

    # Find the input field and enter the text
    input_field = driver.find_element(By.CSS_SELECTOR, '#search-component-wrapper-ssw > core-card > div > div.input-search-wrapper-ssw > core-search')  # Adjust the locator as needed
    input_field.click()
   # input_field.clear()
    input_field.send_keys(Question)
    input_field.send_keys(Keys.RETURN)

    # Wait for the response to be generated (2 minutes)
    time.sleep(50)

    # Find the response field and get the text
    #response_field = driver.find_element(By.CLASS_NAME, 'input-search hydrated')  # Adjust the locator as needed
    #generated_response = response_field.text

    
    response_field = driver.find_element(By.XPATH,'/html/body/div[10]/div/div[3]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div/div[2]')
   #response_field = driver.find_element(By.XPATH, '//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div/div[2]/div/div[1]/div/div/div/div')  # Adjust the locator as needed
    #response_field = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[3]/div[3]/div[2]/smart-search-web-component/div/core-card/div/div[2]/div/div[2]')
    generated_response = response_field.text
    print(generated_response)
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div/div[2]/div/div[1]/div/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div
                                                    #//*[@id="search-component-wrapper-ssw"]/core-card/div/div[2]/div[3]/div[2]/div/div[1]/div
    # Calculate cosine similarity
    similarity = calculate_cosine_similarity(generated_response, expected_response)

    # Compare the generated response with the expected response using cosine similarity
    if similarity >= 0.60:  # Threshold for considering a match (adjust as needed)
        matches.append((SKU,Question ,generated_response, expected_response, similarity))
    else:
        mismatches.append((SKU,Question ,generated_response, expected_response, similarity))

# Close the web driver
#driver.quit()

print(matches)
print(mismatches)
# Out:
# Np0006 The price of the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL) is $35.49 USD.  i None
# modified_url
# https://www.thermofisher.com/order/catalog/product/Np0006?SID=srch-srp-Np0006 Np0006
# The price of the product NP0006 (NuPAGE™ Transfer Buffer (20X)) is $36.81 USD. i
# Give feedback
# Np0006 Concentration of NuPAGE Transfer Buffer (20X) - NP0006
# The concentration of the NuPAGE Transfer Buffer (20X), catalog number NP0006, is 20X.
#
# Sources  4  3
# Additional Data & References
# 1. Western Blot Protocols and Recipes
# 2. NuPAGE Technical Guide (Page: 8, 48)
# 3. NuPAGE™ Transfer Buffer (20X)
# 4. NuPAGE™ Transfer Buffer (20X)
# 5. Western Blot Sample Preparation Protocol
# 6. NuPAGE Large Protein Analysis System (Page: 31)
# 7. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
#  Np0006
# inside else
# Here is the contact information to reach our team.
# How can we help?
# Customer Service
# 800 955 6288
# Customercare@thermofisher.com
# Technical Support
# 800 955 6288
# Contact Technical Support
# Instrument Service
# 800 955 6288
# Contact Instrument Service
# Give feedback
# Np0006 Here is the contact information to reach our team.
# How can we help?
# Customer Service
#
# Contact Customer Service
# Technical Support
# 1234567891
#
# Contact Technical Support
# Instrument Service
# 1234567893
# Random3@gmail.com
# Sales
# Live Chat
# Can't find what you're looking for?
# Find additional support.
#  Np0006
# inside else
# Product NP0006 (NuPAGE™ Transfer Buffer (20X)) is currently In Stock and available for purchase. i
# Give feedback
# Np0006 Yes, the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL) is currently in stock and available for purchase.  i Np0006
# inside else
# Currently, there are no active promotions or discounts available for product NP0006 (NuPAGE™ Transfer Buffer (20X)).
# Give feedback
# Np0006 Currently, there are no active promotions or discounts available for the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL). Np0006
# inside else
# I found the following safety_data_sheets for NP0006
# Safety Data Sheets (1 matches)
# NP0006
# Give feedback
# Np0006 I found the following safety_data_sheets for NP0006
# Safety Data Sheets (1 matches)
# NP0006 Np0006
# inside else
# Certificates (5 matches)
# Lot #
# Certificate Type
# Date
# Catalog Number(s)
# TFHEPUY
# Certificate of Analysis
# Apr 02, 2026
# NP0006
# TF2C1GM
# Certificate of Analysis
# Apr 02, 2026
# NP0006
# TFQAIIRKW
# Certificate of Analysis
# Mar 29, 2026
# NP0006
# TFOT1DT
# Certificate of Analysis
# Mar 27, 2026
# NP0006
# TF8AAQW
# Certificate of Analysis
# Mar 27, 2026
# NP0006
# Here are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below.
# Give feedback
# Np0006 Certificates (5 matches)
# Lot #
# Certificate Type
# Date
# Catalog Number(s)
# TFRSRE26S
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFRSK6JNH
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQALWUGZ
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQAV4VT9
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQARNCPC
# Certificate of Analysis
# Nov 19, 2025
# NP0006
# Here are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below. Np0006
# inside else
# I found the following Manuals for NP0006
# Product Information (5 matches)
# Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format
# Quick Reference Guide: NuPAGE Bis-Tris Midi Gels
# NuPAGE Technical Guide
# NuPAGE Large Protein Analysis System
# Mini Gel Tank and Blot Module QRC
# Give feedback
# Np0006 I found the following Manuals for NP0006
# Product Information (6 matches)
# EquipmentManuals-Np0006
# Operator Manuals - NP0006
# User Manuals - NP0006
# NuPAGE Technical Guide
# NuPAGE Large Protein Analysis System
# Mini Gel Tank and Blot Module QRC Np0006
# inside else
# Attribute NP0006 3500
# Catalog Number NP0006 3500
# Product Title NuPAGE™ Transfer Buffer (20X) HLT 10 MICROPOINT BULK NST 100
# Product Size Each Case of 10000
# Unit of Measure EA CS
# Price (USD) $36.81 Price is not available
# Availability In Stock Not specified
# Is Loyalty Aspire Eligible True False
# Is Recurring Order Eligible True False
# Product Type / Category Transfer Buffer Not specified
# Specifications Buffer: Transfer Buffers
# Concentration: 20X
# Content And Storage: Store at room temperature. Guaranteed stable for 6 months unless otherwise specified.
# Gel Compatibility: NuPAGE™ Gels
# Quantity: 125mL
# Shelf Life: 6 Months
# Shipping Condition: Room Temperature
# Gel Type: NuPAGE
# Product Line: NuPAGE Not specified
# Give feedback
# Np0006 Comparison of NuPAGE Transfer Buffer (20X) (Catalog Number: NP0006) with Product 3500
# Based on the provided information, detailed data is available for NP0006 (NuPAGE Transfer Buffer 20X), but no information is available for product 3500 in the provided context.
#
# NuPAGE Transfer Buffer (20X) - NP0006
# Use: Used to transfer proteins from NuPAGE Bis-Tris and NuPAGE Tris-Acetate gels to membranes for western blotting.
# Buffer Type: Transfer Buffer, 20X concentration.
# Storage: Store at room temperature; guaranteed stable for 6 months.
# Quantity: 125 mL or 1 L options available.
# Compatibility: Compatible with NuPAGE gels.
# Features: Maintains neutral pH to protect amino acid side chains; compatible with N-terminal protein sequencing using Edman degradation.
# Usage: Can be used with Novex Semi-Dry Blotter for semi-dry transfer or XCell II Blot Module for wet transfer.
# Enhancement: NuPAGE Antioxidant can be added to enhance transfer of reduced proteins.
# Shelf Life: 6 months.
# Shipping Condition: Room temperature.
# No information about product 3500 is available in the provided documents, so a direct comparison cannot be made.
#
# If you provide more details or context about product 3500, we can assist further.
#
# Sources  1  3
# Additional Data & References
# 1. NuPAGE™ Transfer Buffer (20X)
# 2. NuPAGE Technical Guide (Page: 38, 48)
# 3. NuPAGE™ Transfer Buffer (20X)
# 4. Western Blot Protocols and Recipes
# 5. NuPAGE Large Protein Analysis System (Page: 1, 4, 31)
#  Np0006
# inside else
# Technical Notes
# There are no specific technical notes provided for product NP0006 in the available documentation.
# Sources 1
# Additional Data & References
# 1. NuPAGE Large Protein Analysis System (Page: 9, 16, 32, 34)
# 2. 2D Gel Electrophoresis Buffers & Reagents
# 3. 2D Gel Electrophoresis Buffers & Reagents
# 4. NuPAGE Technical Guide (Page: 56)
# 5. Western Blot Protocols and Recipes
# Give feedback
# Np0006 Technical Notes for NP0006 (NuPAGE Transfer Buffer 20X)
# The NuPAGE Transfer Buffer (20X) is designed for efficient protein transfer from NuPAGE Bis-Tris and NuPAGE Tris-Acetate gels to membranes during western blotting. It maintains a neutral pH environment established during electrophoresis, which protects amino acid side chains from modification and is compatible with N-terminal protein sequencing using Edman degradation.
#
# This buffer can be used with the Novex Semi-Dry Blotter for semi-dry transfer or with the XCell II Blot Module for wet (tank) transfer. Additionally, NuPAGE Antioxidant may be used with this buffer to enhance the transfer of reduced proteins to membranes.
#
# For detailed protocols and additional technical resources, you may refer to the following guides and manuals available for NP0006:
#
# NuPAGE Technical Guide
# NuPAGE Large Protein Analysis System Manual
# Mini Gel Tank and Blot Module Quick Reference Card
# These documents provide comprehensive instructions and technical details to optimize your western blotting experiments using NP0006.
#
# Sources  1
# Additional Data & References
# 1. NuPAGE Large Protein Analysis System (Page: 9, 16, 32, 34)
# 2. 2D Gel Electrophoresis Buffers & Reagents
# 3. NuPAGE Technical Guide (Page: 56)
# 4. Western Blot Protocols and Recipes
# 5. Western Blot Buffers
#  Np0006
# inside else
# Brochures Available for Western Blotting and Protein Electrophoresis
# We offer several brochures that provide detailed information and guidance on western blotting and protein electrophoresis workflows, including transfer buffers and detection reagents.
# Western Blotting Overview Brochure: This brochure provides an overview of the western blotting workflow, helping users understand the process and optimize their experiments.
# HMW Protein Transfer Application Note: This application note focuses on the transfer of high molecular weight proteins using the iBlot 2 system.
# Western Detection Workflow Brochure: This brochure covers the entire western detection workflow, including blocking buffers, wash buffers, and stripping buffers.
# These brochures can be downloaded from our website and provide valuable insights for optimizing western blot experiments.
# Sources 2
# 4
# Additional Data & References
# 1. NuPAGE Large Protein Analysis System (Page: 32)
# 2. Transfer Buffers for Western Blotting
# 3. Native PAGE Gels
# 4. Western Blot Buffers
# 5. NuPAGE Technical Guide (Page: 3, 56)
# 6. Blocking Buffers for Western Blot and ELISA
# 7. NuPAGE Technical Guide (Page: 56)
# Give feedback
# A43605024 Brochures for NP0006 (NuPAGE Transfer Buffer 20X)
# While there are no specific brochures exclusively for NP0006 listed, related educational and informational brochures are available to support western blotting workflows and protein analysis. These include:
#
# Western Blotting Overview Brochure: Provides an overview of the western blotting workflow, which is relevant when using transfer buffers like NP0006.
# HMW Protein Transfer Application Note: Offers detailed guidance on transferring high molecular weight proteins, which can be useful when using NuPAGE transfer buffers.
# These brochures can be accessed through the Thermo Fisher Scientific website and provide valuable insights into western blotting techniques and protein transfer optimization.
#
# Sources  2
# Additional Data & References
# 1. NuPAGE Large Protein Analysis System (Page: 3, 31, 32)
# 2. Transfer Buffers for Western Blotting
# 3. Western Blot Buffers
# 4. NuPAGE Technical Guide (Page: 1, 56)
# 5. Blocking Buffers for Western Blot and ELISA
#  Np0006
# modified_url
# https://www.thermofisher.com/order/catalog/product/A43605024?SID=srch-srp-A43605024 A43605024
# Contents of the Collibri ES DNA Library Preparation Kit Documentation
# The documentation includes detailed protocols and information sections such as:
# Purify the amplified SARS-CoV-2 genome
# Normalize amplified SARS-CoV-2 genome
# Prepare 96 indexed libraries
# Fragmentation and dA-tailing of input DNA
# Dual indexed adaptor ligation
# Post-ligation cleanup
# Library PCR amplification (optional)
# Purify amplified DNA libraries
# Verify quality and quantity of prepared DNA libraries
# Sequence on an Illumina platform
# Adaptor index sequences and plate layouts
# Chemical and biological hazard safety
# Customer and technical support
# Limited product warranty
# This documentation serves as a comprehensive guide for library preparation and sequencing workflows.
# Sources 1
# 2
# Additional Data & References
# 1. User Guide: Collibri ES DNA Library Prep Kit - for sequencing SARS-CoV-2 with PCR enrichment (Page: 4, 27, 52)
# 2. User Guide: Collibri ES DNA Library Prep Kit - For sequencing SARS-CoV-2 with PCR enrichment using Phusion Plus PCR Master Mix (Page: 4, 49)
# 3. User Guide: Collibri ES DNA Library Prep Kits for Whole Exome Sequencing (Page: 29)
# 4. User Guide: Collibri ES DNA Library Prep Kit for Illumina (Page: 5, 58)
# Give feedback
# 11012044 Related and Alternative Products for NuPAGE™ Transfer Buffer (20X) - NP0006
# Here are the alternative products available for NP0006:
#
# Catalog Number	Product Title	Size	Price (USD)	Availability
# BT0006	Bolt™ Transfer Buffer (20X)	125 mL	$35.88	In Stock
# NP00061	NuPAGE™ Transfer Buffer (20X)	1 L	$234.00	Out Of Stock (Pending)
# This search is not yet fully optimized to provide product recommendations. Please feel free to ask specific questions about this product for more detailed information. A43605024
# modified_url
# https://www.thermofisher.com/order/catalog/product/11012044?SID=srch-srp-11012044 11012044
# I was unable to find specific information about the vitamins and their molecular weights in the provided product documentation for catalog number 11012044. Please contact our Technical Support Team for detailed information.
# Sources i
# Additional Data & References
# 1. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 1, 2, 3)
# 2. FAQ:Where can I find media formulations?
#
# 3. FAQ:Where can I find the osmolality for MEM Medium?
#
# 4. FAQ:Do you have a comparison of dishes, culture plates, and flasks by surface area, seeding density, cells at confluency, and volumes of Versene solution, trypsin, and growth medium?
# 5. FAQ:Can the Gibco Media Configurator be used for my own proprietary formulation?
#
# 6. FAQ:Do you offer assistance with media formulation development?
#
# How can we help?
# Customer Service
# 800 955 6288
# Customercare@thermofisher.com
# Technical Support
# 800 955 6288
# Contact Technical Support
# Sales
# Live Chat
# Give feedback
# NP0006 Comparison of NuPAGE™ Transfer Buffer (20X) - NP0006 with NuPAGE™ MES SDS Running Buffer (20X) - NP0002 and NuPAGE™ Sample Reducing Agent (10X) - NP0004
# Attribute	NP0006	NP0002	NP0004
# Product Title	NuPAGE™ Transfer Buffer (20X)	NuPAGE™ MES SDS Running Buffer (20X)	NuPAGE™ Sample Reducing Agent (10X)
# Catalog Number	NP0006	NP0002	NP0004
# Product Size	125 mL	500 mL	250 µL
# Concentration	20X	20X	500 mM
# Product Type	Transfer Buffer	Running Buffer	Sample Reducing Agent
# Product Line	NuPAGE™	NuPAGE	NuPAGE™
# Storage Condition	Room Temperature	+4°C to 25°C	4°C (Wet Ice Shipping)
# Shelf Life	6 Months	Not specified	6 Months
# Usage	Protein transfer from gels to membranes for western blotting	Running buffer for electrophoresis	Reducing agent for sample preparation
# Availability	In Stock	In Stock	In Stock
# Price (USD)	$35.49	$112.00	$20.77
# Summary: While all three products belong to the NuPAGE product family, NP0006 is a transfer buffer used for protein transfer in western blotting, NP0002 is a running buffer used during electrophoresis, and NP0004 is a sample reducing agent used to prepare samples. They differ in their function, concentration, size, storage conditions, and price. Therefore, they are related but serve distinct roles in protein electrophoresis and western blot workflows.
#
# i
#  11012044
# modified_url
# https://www.thermofisher.com/order/catalog/product/NP0006?SID=srch-srp-NP0006 NP0006
# Concentration of NuPAGE Transfer Buffer (20X) - NP0006
# The concentration of the NuPAGE Transfer Buffer (catalog number NP0006) is 20X.
# This buffer is designed for transferring proteins from NuPAGE Bis-Tris and NuPAGE Tris-Acetate gels to membranes for western blotting, maintaining a neutral pH environment during electrophoresis.
# Additional Data & References
# 1. Western Blot Protocols and Recipes
# 2. NuPAGE Technical Guide (Page: 8, 48)
# 3. NuPAGE Technical Guide (Page: 8, 48)
# 4. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels (Page: 1)
# 5. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format (Page: 1)
# 6. Western Blot Sample Preparation Protocol
# Give feedback
# NP0006 Alternate Products for NuPAGE™ Transfer Buffer (20X) - NP0006
# Catalog Number	Product Title	Size	Price (USD)	Availability
# BT0006	Bolt™ Transfer Buffer (20X)	125 mL	$35.88	In Stock
# NP00061	NuPAGE™ Transfer Buffer (20X)	1 L	$234.00	Out Of Stock (Pending)
# This search is not yet fully optimized to provide product recommendations. Please feel free to ask specific questions about this product for more detailed information. NP0006
# inside else
# Related Products to NP0006 (NuPAGE Transfer Buffer 20X)
# The following electrophoresis reagents and apparatus are related and commonly used with NP0006 for protein separation and analysis:
# Product Quantity Catalog Number
# XCell SureLock1 Mini-Cell 1 unit EI0001
# XCell II1 Blot Module 1 unit EI9051
# PowerEase1 500 Power Supply 1 unit EI8600
# DryEase1 Mini-Gel Drying System 1 Kit NI2387
# StainEase1 Staining Tray 2/pack NI2400
# Gel-Dry1 Drying Solution 500 mL LC4025
# iBlot1 Gel Transfer Device 1 unit IB1001
# Novex1 Semi-Dry Blotter 1 unit SD1000
# NuPAGE1 LDS Sample Buffer (4X) 10 mL NP0007
# 250 mL NP0008
# NuPAGE1 MOPS SDS Running Buffer (20X) 500 mL NP0001
# NuPAGE1 MES SDS Running Buffer (20X) 500 mL NP0002
# NuPAGE1 Tris-Acetate SDS Running Buffer (20X) 500 mL LA0041
# NuPAGE1 Antioxidant 15 mL NP0005
# NuPAGE1 Sample Reducing Agent (10X) 250 bcL NP0004
# 10 mL NP0009
# Novex1 Tris-Glycine Native Running Buffer (10X) 500 mL LC2672
# Novex1 Tris-Glycine Native Sample Buffer (2X) 20 mL LC2673
# Nitrocellulose Membrane 0.2 bcm 20 membrane/filter papers LC2000
# Invitrolon1 PVDF membranes 0.45 bcm 20 membrane/filter papers LC2005
# PVDF membranes 0.2 bcm 20 membrane/filter papers LC2002
# Sources 1
# 2
# Additional Data & References
# 1. NuPAGE Technical Guide (Page: 1, 48)
# 2. NuPAGE Technical Guide (Page: 48)
# 3. Western Blot Protocols and Recipes
# 4. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels (Page: 1)
# 5. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format (Page: 1)
# 6. NuPAGE Large Protein Analysis System (Page: 31)
# 7. Western Blot Sample Preparation Protocol
# Give feedback
# NP0006 Certificates (5 matches)
# Lot #
# Certificate Type
# Date
# Catalog Number(s)
# TFRSRE26S
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFRSK6JNH
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQALWUGZ
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQAV4VT9
# Certificate of Analysis
# Nov 28, 2025
# NP0006
# TFQARNCPC
# Certificate of Analysis
# Nov 19, 2025
# NP0006
# Here are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below.
#  NP0006
# inside else
# Comparison of NP0006 with NP0002 and NP0004
# Attribute NP0006 NP0002 NP0004
# Catalog Number NP0006 NP0002 NP0004
# Product Title NuPAGE™ Transfer Buffer (20X) NuPAGE™ MES SDS Running Buffer (20X) NuPAGE™ Sample Reducing Agent (10X)
# Product Line NuPAGE NuPAGE NuPAGE
# Product Type Transfer Buffer Running Buffer Sample Reducing Agent
# Concentration 20X 20X 500 mM
# Quantity 125mL 500 mL 250μL
# Storage Store at room temperature. Guaranteed stable for 6 months. +4°C to 25°C Store at 4°C. Guaranteed stable for 6 months.
# Physical Form Not specified Liquid Not specified
# pH Not specified 7.3 Not specified
# Shipping Condition Room Temperature Not specified Wet Ice
# Price (USD) $36.81 $111.65 $20.65
# Availability In Stock In Stock In Stock
# Summary: While all three products belong to the NuPAGE product line, NP0006 is a Transfer Buffer, NP0002 is a MES SDS Running Buffer, and NP0004 is a Sample Reducing Agent. They serve different roles in electrophoresis workflows. NP0006 and NP0002 share the same concentration of 20X but differ in buffer type and volume. NP0004 has a different concentration and function. All are available in stock.
# Give feedback
# NP0006 Sorry, I can only assist with inquiries related to this specific product. Please contact Customer Service or visit Generate a Web Quote page for further assistance.
# How can we help?
# Customer Service
#
# Contact Customer Service
# Technical Support
# 1234567891
#
# Contact Technical Support
# Instrument Service
# 1234567893
# Random3@gmail.com
# Sales
# Live Chat
# Can't find what you're looking for?
# Find additional support. NP0006
# inside else
# Alternate Products for NP0006 (NuPAGE™ Transfer Buffer (20X))
# Catalog Number Product Title Quantity Price (USD) Availability
# BT00061 Bolt™ Transfer Buffer (20X) Each $240.65 In Stock
# This search is not yet fully optimized to provide product recommendations. Please feel free to ask specific questions about this product for more detailed information.
# i
# Give feedback
# NP0006 Detection of Binding Between Matrix GLA Protein (MGP) and Bone Morphogenetic Protein-2 (BMP-2)
# The binding between MGP and BMP-2 can be detected using immunoprecipitation techniques. Specifically, MGP and BMP-2 are tagged with FLAG and c-Myc tags, respectively. Immunoprecipitation is then performed using these tagged proteins, and co-precipitation of BMP-2 with MGP indicates binding between the two proteins.
#
# This method allows for the identification and confirmation of the interaction between MGP and BMP-2.
#
# Sources  1
# Additional Data & References
# 1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.
# 2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
# 3. NuPAGE Tris-Acetate Gels
# 4. Native PAGE Gels
# 5. NuPAGE Technical Guide (Page: 36, 46)
# 6. Blocking Buffers for Western Blot and ELISA
# 7. FAQ:Is the NuPAGE Transfer buffer compatible with N-terminal sequencing of proteins via Edman degradation?
#  NP0006
# inside else
# Certificates (5 matches)
# Lot #
# Certificate Type
# Date
# Catalog Number(s)
# TFHEPUY
# Certificate of Analysis
# Apr 02, 2026
# NP0006
# TF2C1GM
# Certificate of Analysis
# Apr 02, 2026
# NP0006
# TFQAIIRKW
# Certificate of Analysis
# Mar 29, 2026
# NP0006
# TFOT1DT
# Certificate of Analysis
# Mar 27, 2026
# NP0006
# TF8AAQW
# Certificate of Analysis
# Mar 27, 2026
# NP0006
# Here are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below.
# Give feedback
# NP0006 Product inquiries require a catalog number. We've found these potential matches for your search "rhlaminin-521". If the product you wish to inquire isn't shown in this list, please enter a catalog number in the text box below.
#
#
# rhLaminin-521, 1 mg
# Catalog Number: A29249
#
# Essential 8™ Adaptation Kit
# Catalog Number: A25935
#
# Pluripotent Stem Cell (PSC) Gene Editing Demo Kit
# Catalog Number: A43203 NP0006
# inside else
# We have agents available now that can assist you with this query! Please connect with them by selecting the team available in the open chat window to get started.
# Give feedback
# NP0006 Shipping Condition of NuPAGE Sample Reducing Agent (10X) - NP0004
# The NuPAGE Sample Reducing Agent (10X) is shipped on wet ice to ensure stability during transport.
#
# Additional Data & References
# 1. Quick Reference: NuPAGE Bis-Tris Mini Gels (Page: 1)
# 2. NuPAGE™ Sample Reducing Agent (10X)
# 3. NuPAGE™ Sample Reducing Agent (10X)
# 4. FAQ:How should I store the NuPAGE Sample Reducing agent and NuPAGE Antioxidant?
# 5. Immunoprecipitation using Protein A - 10006D
# 6. Immunoprecipitation using Protein G - 10007D
# 7. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
# 8. Protein Electrophoresis Buffers and Reagents NP0006
# inside else
# Detection of Binding Between MGP and BMP-2
# Binding between Matrix GLA protein (MGP) and bone morphogenetic protein-2 (BMP-2) can be detected using immunoprecipitation techniques. In the described study, MGP and BMP-2 were tagged with FLAG and c-Myc, respectively. Immunoprecipitation was performed using these tagged proteins, and the results showed co-precipitation of BMP-2 with MGP, indicating binding.
# Sources 1
# Additional Data & References
# 1. Matrix GLA protein, a regulatory protein for bone morphogenetic protein-2.
# 2. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels
# 3. NuPAGE Tris-Acetate Gels
# 4. Native PAGE Gels
# 5. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format (Page: 3)
# 6. NuPAGE Technical Guide (Page: 36, 46)
# 7. NuPAGE Technical Guide (Page: 36)
# Give feedback
# NP0006 产品比较：NuPAGE™ Transfer Buffer (20X) - NP0006 与 NuPAGE™ Transfer Buffer (20X), 1L - NP00061
# 属性	NP0006	NP00061
# 目录号	NP0006	NP00061
# 产品名称	NuPAGE™ Transfer Buffer (20X)	NuPAGE™ Transfer Buffer (20X)
# 规格/容量	125 mL	1 L
# 浓度	20X	20X
# 价格 (USD)	$35.49	$234.00
# 库存状态	In Stock	Out Of Stock (Pending)
# 适用凝胶类型	NuPAGE™ Gels	未具体说明
# 储存条件	室温	未具体说明
# 保质期	6个月	未具体说明 NP0006
# inside else
# Sterility of rhLaminin-521
# The provided product information does not include any details regarding the sterility of rhLaminin-521. Therefore, we cannot confirm if rhLaminin-521 is sterile based on the available data.
# For specific information about the sterility or other quality attributes of rhLaminin-521, we recommend consulting the product's Certificate of Analysis (COA) or contacting our Technical Support Team.
# Sources 1
# 2
# 3
# 4
# 5
# 6
# Additional Data & References
# 1. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels (Page: 1)
# 2. NuPAGE Large Protein Analysis System (Page: 4, 30, 31)
# 3. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format (Page: 1)
# 4. Western Blot Protocols and Recipes
# 5. Protein Electrophoresis Buffers and Reagents
# 6. Protein Electrophoresis Buffers and Reagents
# How can we help?
# Customer Service
# 800 955 6288
# Customercare@thermofisher.com
# Technical Support
# 800 955 6288
# Contact Technical Support
# Instrument Service
# 800 955 6288
# Contact Instrument Service
# Sales
# Live Chat
# Give feedback
# NP0006 I found the following Lulls for A43605024
# Scientific Resources (1 matches)
# License #443 - thin-well microplate, microtitration plate, Twintec NP0006
# inside else
# Shipping Conditions for NuPAGE Sample Reducing Agent (Cat. No. NP0004)
# The product should be shipped on wet ice to maintain stability during transport.
# Additional Data & References
# 1. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format (Page: 1, 4)
# 2. Quick Reference Guide: NuPAGE Bis-Tris Mini Gels (Page: 1, 4)
# 3. Quick Reference Guide: NuPAGE Bis-Tris Midi Gels (Page: 1, 4)
# 4. Immunoprecipitation using Protein A - 10006D
# 5. Immunoprecipitation using Protein G - 10007D
# Give feedback
# A43605024 Vitamins and Their Molecular Weights in MEM, Hanks' Balanced Salts, powder (Catalog Number 11012044)
# Vitamin	Molecular Weight
# Choline chloride	140.0
# D-Calcium pantothenate	477.0
# Folic Acid	441.0
# Niacinamide	122.0
# Pyridoxal hydrochloride	204.0
# Riboflavin	376.0
# Thiamine hydrochloride	337.0
# i-Inositol	180.0
# Sources  1
# Additional Data & References
# 1. https://www.thermofisher.com/us/en/home/technical-resources/media-formulation.205.html (Page: 1)
# 2. Product Sheet: Media and Balanced Salt Solutions Preparation from Powder and Concentrates (Page: 2, 3)
# 3. Media Preparation from Powder and Concentrates
# 4. MEM, Hanks' Balanced Salts, powder
# 5. Fetal Bovine Serum
# 6. One Shot FBS
# 7. FAQ:Where can I find media formulations?
#  NP0006
# modified_url
# https://www.thermofisher.com/order/catalog/product/A43605024?SID=srch-srp-A43605024 A43605024
# Main Challenges Associated with cfDNA Library Preparation
# Circulating cell-free DNA (cfDNA) library preparation presents several challenges due to the nature of the input material and sample variability:
# Limited Quantity: cfDNA is present in very limited quantities in blood samples, typically in the low ng/mL range, making it difficult to obtain sufficient material for sequencing.
# Degraded DNA: cfDNA is often degraded because it is fragmented during apoptosis, resulting in short fragments (~170 bp), and further degradation can occur in peripheral circulation.
# Genomic DNA Contamination: Presence of genomic DNA (gDNA) from white blood cells due to mechanical damage during sample processing and storage can contaminate cfDNA samples, complicating the enrichment of cfDNA.
# Variability in cfDNA Amounts: There is considerable variation in cfDNA amounts depending on sample type, complicating workflow standardization.
# Low Quality of Input Material: The fragmented and degraded nature of cfDNA makes efficient and reproducible extraction essential for successful library preparation and downstream analysis.
# These challenges require specialized protocols and careful handling to ensure high-quality sequencing libraries from cfDNA.
# Sources 1
# Additional Data & References
# 1. Application note: Library preparation from circulating cell-free DNA (Page: 1, 2, 4)
# 2. Tech Note: Scaling library preparation and maintaining quality (Page: 1, 2)
# 3. Tech Note: Impact of GC bias on library preparation (Page: 1)
# 4. User Guide: Collibri ES DNA Library Prep Kit for Illumina (Page: 15)
# 5. FAQ:How do I assess the quality of the prepared Collibri DNA library?
#
# Give feedback
# L7526 Fixation of Cells After Staining with LysoTracker Green DND-26
# LysoTracker Green DND-26 is a cell-permeable, green fluorescent dye that stains acidic compartments such as lysosomes in live cells. However, it is non-fixable, meaning that the staining pattern is not retained after fixation procedures. Therefore, cells cannot be fixed after staining with LysoTracker Green DND-26 if you want to preserve the fluorescent signal.
#
# In contrast, some other LysoTracker dyes, such as LysoTracker Red DND-99, usually retain their staining pattern following fixation with aldehydes.
#
# Summary
# LysoTracker Green DND-26 staining is not retained after fixation.
# For fixation after staining, consider using dyes like LysoTracker Red DND-99 which are fixable.
# Refer to the product storage and handling guidelines to ensure optimal staining results.
#
# Sources  6  1  4
# Additional Data & References
# 1. LysoTracker and LysoSensor Probes (Page: 1, 3, 4)
# 2. Probes for Lysosomes, Peroxisomes and Yeast Vacuoles—Section 12.3
# 3. Live intracellular super-resolution imaging using site-specific stains.
# 4. LysoTracker™ Green DND-26, special packaging
# 5. Effect of cryopreservation of bovine sperm organelle function and viability as determined by flow cytometry.
# 6. Comparative pathogenesis of haloacetic acid and protein kinase inhibitor embryotoxicity in mouse whole embryo culture.
#  A43605024
# modified_url
# https://www.thermofisher.com/order/catalog/product/L7526?SID=srch-srp-L7526 L7526
# Fixation After Staining with LysoTracker Green DND-26
# LysoTracker Green DND-26 is a cell-permeable, non-fixable dye that stains acidic compartments such as lysosomes. Because it is non-fixable, the staining is not retained after fixation of cells. This means that if you fix the cells after staining with LysoTracker Green DND-26, the fluorescent signal will likely be lost.
# In contrast, some other LysoTracker probes, such as LysoTracker Red DND-99, usually retain their staining pattern following fixation with aldehydes.
# Summary
# LysoTracker Green DND-26: non-fixable, staining not retained after fixation.
# LysoTracker Red DND-99: staining usually retained after fixation.
# Therefore, if fixation after staining is required, consider using a fixable LysoTracker probe like LysoTracker Red DND-99 instead of LysoTracker Green DND-26.
# Sources 1
# Additional Data & References
# 1. Probes for Lysosomes, Peroxisomes and Yeast Vacuoles—Section 12.3
# 2. LysoTracker and LysoSensor Probes (Page: 1, 3, 4)
# 3. Live intracellular super-resolution imaging using site-specific stains.
# 4. Effect of cryopreservation of bovine sperm organelle function and viability as determined by flow cytometry.
# 5. Comparative pathogenesis of haloacetic acid and protein kinase inhibitor embryotoxicity in mouse whole embryo culture.
# 6. Fluorometric assessments of acrosomal integrity and viability in cryopreserved bovine spermatozoa.
# Give feedback
# NP0006 Main Challenges Associated with cfDNA Library Preparation
# Preparing libraries from circulating cell-free DNA (cfDNA) presents several significant challenges:
#
# Limited Quantity of Material: cfDNA is present in very low quantities in blood samples, typically in the low ng/mL range, making it difficult to obtain sufficient input material for library preparation.
# Degraded DNA Quality: cfDNA is often degraded due to apoptosis and exposure to peripheral circulation conditions, resulting in fragmented DNA primarily around 170 base pairs.
# Genomic DNA Contamination: Contamination from larger genomic DNA (gDNA) molecules originating from white blood cells can occur due to mechanical damage during sample processing and storage, complicating the enrichment of cfDNA.
# Variability in cfDNA Amounts: There is considerable variation in cfDNA concentration depending on sample type, which complicates workflow standardization and quantification prior to extraction.
# These challenges necessitate efficient and reproducible extraction and library preparation methods to ensure high-quality sequencing data from cfDNA samples.
#
# Sources  1
# Additional Data & References
# 1. Application note: Library preparation from circulating cell-free DNA (Page: 1, 2, 4)
# 2. Tech Note: Scaling library preparation and maintaining quality (Page: 1, 2)
# 3. Tech Note: Impact of GC bias on library preparation (Page: 1)
# 4. User Guide: Collibri ES DNA Library Prep Kit for Illumina (Page: 15)
# 5. FAQ:How do I assess the quality of the prepared Collibri DNA library?
#  L7526
# modified_url
# https://www.thermofisher.com/order/catalog/product/NP0006?SID=srch-srp-NP0006 NP0006
# 属性 NP0006 NP00061
# 产品名称 NuPAGE™ Transfer Buffer (20X) NuPAGE™ Transfer Buffer (20X), 1L
# 规格浓度 20X 20X
# 容量 125mL 1L
# 价格 (USD) 36.81 243.00
# 库存状态 In Stock In Stock
#
# 总结：两款产品均为20X浓度的NuPAGE转移缓冲液，主要区别在于容量和价格，NP0006为125mL，价格为36.81美元；NP00061容量为1L，价格为243.00美元。 i
# Give feedback
# [('Np0006', 'what is price of product', 'The price of the product NP0006 (NuPAGE™ Transfer Buffer (20X)) is $36.81 USD. i\nGive feedback', 'The price of the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL) is $35.49 USD.  i', 0.6392306240536286), ('L7526', 'Can I fix the cells after staining?', 'Fixation After Staining with LysoTracker Green DND-26\nLysoTracker Green DND-26 is a cell-permeable, non-fixable dye that stains acidic compartments such as lysosomes. Because it is non-fixable, the staining is not retained after fixation of cells. This means that if you fix the cells after staining with LysoTracker Green DND-26, the fluorescent signal will likely be lost.\nIn contrast, some other LysoTracker probes, such as LysoTracker Red DND-99, usually retain their staining pattern following fixation with aldehydes.\nSummary\nLysoTracker Green DND-26: non-fixable, staining not retained after fixation.\nLysoTracker Red DND-99: staining usually retained after fixation.\nTherefore, if fixation after staining is required, consider using a fixable LysoTracker probe like LysoTracker Red DND-99 instead of LysoTracker Green DND-26.\nSources 1\nAdditional Data & References\n1. Probes for Lysosomes, Peroxisomes and Yeast Vacuoles—Section 12.3\n2. LysoTracker and LysoSensor Probes (Page: 1, 3, 4)\n3. Live intracellular super-resolution imaging using site-specific stains.\n4. Effect of cryopreservation of bovine sperm organelle function and viability as determined by flow cytometry.\n5. Comparative pathogenesis of haloacetic acid and protein kinase inhibitor embryotoxicity in mouse whole embryo culture.\n6. Fluorometric assessments of acrosomal integrity and viability in cryopreserved bovine spermatozoa.\nGive feedback', 'Fixation of Cells After Staining with LysoTracker Green DND-26\nLysoTracker Green DND-26 is a cell-permeable, green fluorescent dye that stains acidic compartments such as lysosomes in live cells. However, it is non-fixable, meaning that the staining pattern is not retained after fixation procedures. Therefore, cells cannot be fixed after staining with LysoTracker Green DND-26 if you want to preserve the fluorescent signal.\n\nIn contrast, some other LysoTracker dyes, such as LysoTracker Red DND-99, usually retain their staining pattern following fixation with aldehydes.\n\nSummary\nLysoTracker Green DND-26 staining is not retained after fixation.\nFor fixation after staining, consider using dyes like LysoTracker Red DND-99 which are fixable.\nRefer to the product storage and handling guidelines to ensure optimal staining results.\n\nSources  6  1  4\nAdditional Data & References\n1. LysoTracker and LysoSensor Probes (Page: 1, 3, 4)\n2. Probes for Lysosomes, Peroxisomes and Yeast Vacuoles—Section 12.3\n3. Live intracellular super-resolution imaging using site-specific stains.\n4. LysoTracker™ Green DND-26, special packaging\n5. Effect of cryopreservation of bovine sperm organelle function and viability as determined by flow cytometry.\n6. Comparative pathogenesis of haloacetic acid and protein kinase inhibitor embryotoxicity in mouse whole embryo culture.\n', 0.8970727453318564)]
# [('Np0006', 'Is there contact  us details', 'Here is the contact information to reach our team.\nHow can we help?\nCustomer Service\n800 955 6288\nCustomercare@thermofisher.com\nTechnical Support\n800 955 6288\nContact Technical Support\nInstrument Service\n800 955 6288\nContact Instrument Service\nGive feedback', 'Concentration of NuPAGE Transfer Buffer (20X) - NP0006\nThe concentration of the NuPAGE Transfer Buffer (20X), catalog number NP0006, is 20X.\n\nSources  4  3\nAdditional Data & References\n1. Western Blot Protocols and Recipes\n2. NuPAGE Technical Guide (Page: 8, 48)\n3. NuPAGE™ Transfer Buffer (20X)\n4. NuPAGE™ Transfer Buffer (20X)\n5. Western Blot Sample Preparation Protocol\n6. NuPAGE Large Protein Analysis System (Page: 31)\n7. NuPAGE Bis-Tris and Bolt Bis-Tris Plus Gels\n', 0.023144489977317093), ('Np0006', 'Is this available for purchase?', 'Product NP0006 (NuPAGE™ Transfer Buffer (20X)) is currently In Stock and available for purchase. i\nGive feedback', "Here is the contact information to reach our team.\nHow can we help?\nCustomer Service\n\nContact Customer Service\nTechnical Support\n1234567891\n\nContact Technical Support\nInstrument Service\n1234567893\nRandom3@gmail.com\nSales\nLive Chat\nCan't find what you're looking for?\nFind additional support.\n", 0.03168612945949602), ('Np0006', 'promo codes', 'Currently, there are no active promotions or discounts available for product NP0006 (NuPAGE™ Transfer Buffer (20X)).\nGive feedback', 'Yes, the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL) is currently in stock and available for purchase.  i', 0.3360969272762575), ('Np0006', 'SDS', 'I found the following safety_data_sheets for NP0006\nSafety Data Sheets (1 matches)\nNP0006\nGive feedback', 'Currently, there are no active promotions or discounts available for the product NP0006 (NuPAGE™ Transfer Buffer (20X), 125 mL).', 0.1394443826459862), ('Np0006', 'any certificates ', "Certificates (5 matches)\nLot #\nCertificate Type\nDate\nCatalog Number(s)\nTFHEPUY\nCertificate of Analysis\nApr 02, 2026\nNP0006\nTF2C1GM\nCertificate of Analysis\nApr 02, 2026\nNP0006\nTFQAIIRKW\nCertificate of Analysis\nMar 29, 2026\nNP0006\nTFOT1DT\nCertificate of Analysis\nMar 27, 2026\nNP0006\nTF8AAQW\nCertificate of Analysis\nMar 27, 2026\nNP0006\nHere are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below.\nGive feedback", 'I found the following safety_data_sheets for NP0006\nSafety Data Sheets (1 matches)\nNP0006', 0.17414895566208605), ('Np0006', 'manuals ', 'I found the following Manuals for NP0006\nProduct Information (5 matches)\nQuick Reference Guide: NuPAGE Bis-Tris Midi Gels, WedgeWell Format\nQuick Reference Guide: NuPAGE Bis-Tris Midi Gels\nNuPAGE Technical Guide\nNuPAGE Large Protein Analysis System\nMini Gel Tank and Blot Module QRC\nGive feedback', "Certificates (5 matches)\nLot #\nCertificate Type\nDate\nCatalog Number(s)\nTFRSRE26S\nCertificate of Analysis\nNov 28, 2025\nNP0006\nTFRSK6JNH\nCertificate of Analysis\nNov 28, 2025\nNP0006\nTFQALWUGZ\nCertificate of Analysis\nNov 28, 2025\nNP0006\nTFQAV4VT9\nCertificate of Analysis\nNov 28, 2025\nNP0006\nTFQARNCPC\nCertificate of Analysis\nNov 19, 2025\nNP0006\nHere are the 5 latest certificate(s). If you can't find the one you're looking for, please provide the LOT number below.", 0.0627267214827835), ('Np0006', 'product compare with 3500', 'Attribute NP0006 3500\nCatalog Number NP0006 3500\nProduct Title NuPAGE™ Transfer Buffer (20X) HLT 10 MICROPOINT BULK NST 100\nProduct Size Each Case of 10000\nUnit of Measure EA CS\nPrice (USD) $36.81 Price is not available\nAvailability In Stock Not specified\nIs Loyalty Aspire Eligible True False\nIs Recurring Order Eligible True False\nProduct Type / Category Transfer Buffer Not specified\nSpecifications Buffer: Transfer Buffers\nConcentration: 20X\nContent And Storage: Store at room temperature. Guaranteed stable for 6 months unless otherwise specified.\n ...

# %%
now=datetime.datetime.now()
formatted_date_time = now.strftime("%Y-%m-%d %H:%M:%S")
print ("current date time is "+ str(formatted_date_time))
# Out:
# current date time is 2026-04-03 22:51:23

# %%
matchingResults="matches_report_QuickProdPDP"+str(now.strftime("%Y-%m-%d %H_%M_%S"))
mismatchingResults="mismatches_report_QuickProdPDP"+str(now.strftime("%Y-%m-%d %H_%M_%S"))

# %%
matchingResults, mismatchingResults
# Out:
# ('matches_report_QuickProdPDP2026-04-03 22_51_23',
#  'mismatches_report_QuickProdPDP2026-04-03 22_51_23')

# %%
# Generate the report
matches_report = pd.DataFrame(matches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
#matches_report.to_excel(matchingResults, index=False)
matches_report.to_csv(matchingResults+"_"+country_code+".csv", index=False)

mismatches_report = pd.DataFrame(mismatches, columns=["SKU","Question", 'Generated Response', 'Expected Response', 'Cosine Similarity'])
#mismatches_report.to_excel(mismatchingResults, index=False)
mismatches_report.to_csv(mismatchingResults+"_"+country_code+".csv", index=False)

print("Report generated successfully.")
# Out:
# Report generated successfully.
