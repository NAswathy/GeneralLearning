# %%
print ("hello world!")
# Out:
# hello world!

# %%
import numpy as np
import pandas as pd

# %%
import os, asyncio

# %%
ls ./
# Out:
# _SELECT_uch_ucq_FROM_user_chat_history_uch_INNER_JOIN_user_chat__202506102200.csv
# ~$AswathyN_BioHubPresentation_Jan2026.pptx
# ~$eateNewAppCIItemInCMDB.docx
# ~$QuickRegressionTesting5.xlsx
# 2026-01-05/
# all_comparisons.xlsx
# AswathyN_BioHubPresentation_Jan2026.pptx
# AswathyN_DCPIdeas.xlsx
# AswathyN_IBABSilverJubileCelebrations.pptx
# chatIds_checkDup.csv
# Dec6_Jan6_messages-ResponseComparison_AN.xlsx
# dup_chatIds.txt
# FAQ-04012024.xls
# FAQ-06062024.xls
# FAQ.xls
# FAQ25062025.xls
# matches_report_ProdPDP_US.csv
# matches_report_ProdPDP.csv
# matches_report_ProdPDP2025-11-17 11_26_38.xlsx
# matches_report_ProdPDP2025-11-20 15_33_10.xlsx
# matches_report_ProdPDP2025-12-04 09_06_16.xlsx
# matches_report_QAPDP_US_2025-12-24 16_08_41.csv
# matches_report_QAPDP_US_2025-12-24 17_09_46.csv
# matches_report_QAPDP_US_2026-01-08 16_32_17.csv
# matches_report_QAPDP_US_2026-01-09 11_57_47.csv
# matches_report_QAPDP_US_2026-01-15 20_54_23.csv
# ...

# %%
# !pip install openai-agents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# ...

# %%
from agents import Agent, Runner

# %%
car_advisor=Agent()
